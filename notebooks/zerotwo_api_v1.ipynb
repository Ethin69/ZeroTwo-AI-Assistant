# %%
# !pip install cohere python-dotenv
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 4.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/596.3 kB ? eta -:--:--
#    ---------------------------------------- 596.3/596.3 kB 9.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.6 MB 6.9 MB/s eta 0:00:01
#    -------------------- ------------------- 1.8/3.6 MB 5.4 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.6 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.6/3.6 MB 4.8 MB/s eta 0:00:00
# ...
#
#    ------ --------------------------------- 1/6 [hf-xet]
#    ------------- -------------------------- 2/6 [fastavro]
# ...

# %%
import cohere
import os

print("ZeroTwo system initializing...")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import cohere
#       2 import os
#       4 print("ZeroTwo system initializing...")
#
# ModuleNotFoundError: No module named 'cohere'

# %%
import sys
# !{sys.executable} -m pip install cohere python-dotenv

# %%
import cohere
import os

print("ZeroTwo system initializing...")
# Out:
# ZeroTwo system initializing...

# %%
import cohere

API_KEY = "Tr4txnY42HFhKOcDKkgb7cgr43jPBefiZatyUqOe"

co = cohere.Client(API_KEY)

name = input("What should ZeroTwo call you? ")

print("\nZeroTwo system online...\n")

while True:
    user_input = input(f"{name}: ")

    response = co.chat(
        model="command-r7b-12-2024",
        message=f"""
                You are ZeroTwo, a tactical AI assistant.

                Speak concisely.
                Call the user {name}.
                Help with studying, productivity, and planning.

                User question:
                {user_input}
                """,
        temperature=0.7,
        max_tokens=120
    )

    print("\nZeroTwo:", response.text)
# Out:
# What should ZeroTwo call you?  Saiyan
# ZeroTwo system online...
# Saiyan:  What should i study today?
# ZeroTwo: Hey Saiyan!
#
# I can't tell you what to study specifically without knowing your goals and interests.
#
# But here are some tips to help you decide:
#
# * **Think about your goals:** What do you want to achieve academically or professionally? What subjects align with those goals?
# * **Consider your strengths and weaknesses:** Play to your strengths and work on improving areas you struggle with.
# * **Explore your interests:** Choose subjects that spark your curiosity and passion. This will make studying more enjoyable.
# * **Prioritize:** Make a list of subjects and rank them
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 12
#       9 print("\nZeroTwo system online...\n")
#      11 while True:
# ---> 12     user_input = input(f"{name}: ")
# ...
